# %%
# %pip install networkx pulp

import json
import networkx as nx
from random import Random


file = open("map_ia.json")
data = json.load(file)

adjacencies = data["adj"]
# TODO: Shits the bed if there's anything other than letters and _
countyNames = data["county"]
pop = data["pop"]

# adjacencies = []
# countyNames = []
# pop = []
# for countyInfo in data:
#     countyNames.append(countyInfo["GEOID"])
#     adjacencies.append(countyInfo["adj"])
#     pop.append(countyInfo["pop"])


# Number of districts
NUM_DISTRICTS = 5

# Population Tolerance
ALPHA = .05

stateGraph = nx.Graph()

r =  Random(51535162)
totalPop = 0
# Add the nodes as necessary

for i in range(len(adjacencies)):
    # Adds node for each set of adjacencies
    totalPop += pop[i]
    # Adds necessary edges; double-adding doesn't matter
    try:
        for j in adjacencies[i]:
            # Add edge with uniformly random weight 0, 10
            stateGraph.add_edge(countyNames[i], countyNames[j], weight=r.uniform(1, 10))
    except:
            stateGraph.add_edge(countyNames[i], countyNames[adjacencies[i]], weight=r.uniform(1, 10))

# Population per district
targetPop = totalPop / NUM_DISTRICTS

# Binary indicators, defined as 1 if in node in same partitition as 
# source S or 0 in same as sink O. Initializes to 0.
V = [0 for i in range(stateGraph.order())]

# 
Y = [[0 for i in range(stateGraph.order())] for j in range(stateGraph.order())]

# nx.draw(stateGraph)
# Out:
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.0)
# Requirement already satisfied: pulp in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pulp 

def CutPartition(remainingGraph):
    prog = pulp.LpProblem("CutPartition", pulp.LpMinimize)

    # Defining Partition Binary
    xVars = []
    xVarMap = {}
    for n in remainingGraph.nodes:
        var = pulp.LpVariable("x" + str(n), cat=pulp.LpBinary)
        xVarMap[n] = var
        xVars.append(var)
        prog += var
    # Defining crossing binary
    edgeVars = []
    weights = []
    for n, m in remainingGraph.edges:
        edgeVal = pulp.LpAffineExpression([(xVarMap[n], 1), (xVarMap[m], -1)])
        absEdgeVal = pulp.LpVariable('y' + str(n) + str(m), cat=pulp.LpBinary)

        # Tries to fix absolute value prob
        prog += absEdgeVal >= edgeVal
        prog += absEdgeVal >= -edgeVal

        edgeVars.append(absEdgeVal)
        weights.append(remainingGraph[n][m]['weight'])
    # Subset sum
    popVariables = []
    for i in range(len(xVars)):
        popVariables.append(pulp.LpAffineExpression(xVars[i] * pop[i]))
    # Max Pop
    prog += pulp.lpSum(popVariables) <= targetPop * (1 + ALPHA)
    # Min Pop
    prog += pulp.lpSum(popVariables) >= targetPop * (1 - ALPHA)

    # Source Partition Connected
    for i in range(len(xVars)):
        sumParts = []
        for j in range(len(xVars)):
            if i == j: break
            if remainingGraph.has_edge(i, j):
                sumParts.append(remainingGraph[i][j]['weight'] * xVars[j])
        totalLH = pulp.LpAffineExpression(xVars[i] * pulp.lpSum(sumParts))
        prog += pulp.LpConstraint(totalLH, pulp.LpConstraintGE, 0)
    # Define Minimization Target
    # Edgeweights
    edgeWeightVars = []
    for i in range(len(edgeVars)):
        edgeWeightVars.append(pulp.LpAffineExpression(edgeVars[i] * weights[i]))
    prog += pulp.LpAffineExpression(pulp.lpSum(edgeWeightVars), name="Z")

    print("Sending to solver...")
    Solver_name = 'PULP_CBC_CMD'
    solver = pulp.getSolver(Solver_name, threads=6)
    soln = prog.solve(solver)

    print(soln)

    toReturn = {}

    districtPop = 0
    for i in range(len(xVars)):
        if(xVars[i].value() == 1):
            districtPop += pop[i]
            toReturn[xVars[i].name] = xVars[i].value()
            print(xVars[i].name, xVars[i].value())
    if(districtPop >= targetPop * (1 + ALPHA) or districtPop <= targetPop * (1-ALPHA)):
        raise ValueError("District Generated not of Proper Population") 
    return toReturn


remainingGraph = stateGraph.copy()
districts = []
while len(districts) < NUM_DISTRICTS - 1:
    cutResult = CutPartition(remainingGraph)
    newDistrict = []
    for d in cutResult.keys():
        # Gets rid of the x
        # print(d)
        newDistrict.append(d[1:])
    # Appends the new district to our list of districts
    districts.append(newDistrict)
    oldSize = remainingGraph.order()
    # Removes those nodes from the district
    remainingGraph.remove_nodes_from(newDistrict)
    newSize = remainingGraph.order()
    # Verify that all of the nodes were removed
    if(newSize != oldSize - len(newDistrict)):
        print(remainingGraph.nodes)
        print(newDistrict)
        raise(ValueError("Districts were not removed appropriately"))
    # print(newDistrict)
newDistrict = []
for d in remainingGraph.nodes:
    # Gets rid of the x
    newDistrict.append(d)
districts.append(newDistrict)

#Confirm total size is appropriate
totalCountiesinDistricts = 0
for d in districts:
    totalCountiesinDistricts += len(d)
if(totalCountiesinDistricts != len(countyNames)):
    raise(ValueError("Number of districts in plan does not match number of districts."))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/pulp.py:1668: UserWarning: Overwriting previously set objective.
#   warnings.warn("Overwriting previously set objective.")
# Sending to solver...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/z3/3qb7cv41693fmz3b6hbntjkr0000gn/T/ceed81726a6344a5b0ee061425e67523-pulp.mps -threads 6 -timeMode elapsed -branch -printingOptions all -solution /var/folders/z3/3qb7cv41693fmz3b6hbntjkr0000gn/T/ceed81726a6344a5b0ee061425e67523-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 550 COLUMNS
# At line 2945 RHS
# At line 3491 BOUNDS
# At line 3813 ENDATA
# Problem MODEL has 545 rows, 321 columns and 1530 elements
# Coin0008I MODEL read with 0 errors
# threads was changed from 0 to 6
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 445 rows, 321 columns (321 integer (321 of which binary)) and 1431 elements
# Cbc0038I Initial state - 99 integers unsatisfied sum - 18.81
# Cbc0038I Pass   1: suminf.    1.97602 (4) obj. 51.2864 iterations 186
# Cbc0038I Pass   2: suminf.    1.97602 (4) obj. 51.2864 iterations 10
# Cbc0038I Pass   3: suminf.    0.10707 (1) obj. 60.3633 iterations 44
# Cbc0038I Pass   4: suminf.    0.23666 (1) obj. 60.3633 iterations 24
# Cbc0038I Pass   5: suminf.    0.98801 (2) obj. 269.506 iterations 96
# Cbc0038I Pass   6: suminf.    0.98801 (2) obj. 269.506 iterations 37
# Cbc0038I Pass   7: suminf.    0.10707 (1) obj. 271.169 iterations 32
# Cbc0038I Pass   8: suminf.    0.23666 (1) obj. 271.169 iterations 20
# Cbc0038I Pass   9: suminf.    1.65349 (4) obj. 394.715 iterations 89
# Cbc0038I Pass  10: suminf.    0.04554 (2) obj. 400.062 iterations 42
# Cbc0038I Pass  11: suminf.    0.30104 (2) obj. 400.062 iterations 26
# Cbc0038I Pass  12: suminf.    0.70637 (3) obj. 577.152 iterations 114
# Cbc0038I Pass  13: suminf.    0.10587 (1) obj. 581.035 iterations 48
# Cbc0038I Pass  14: suminf.    0.23546 (1) obj. 581.035 iterations 17
# Cbc0038I Pass  15: suminf.    0.41971 (2) obj. 565.261 iterations 78
# Cbc0038I Pass  16: suminf.    0.41971 (2) obj. 565.261 iterations 29
# Cbc0038I Pass  17: suminf.    0.33944 (1) obj. 569.807 iterations 22
# Cbc0038I Pass  18: suminf.    0.20986 (1) obj. 569.807 iterations 16
# Cbc0038I Pass  19: suminf.    2.40869 (5) obj. 654.414 iterations 82
# Cbc0038I Pass  20: suminf.    0.72171 (2) obj. 666.297 iterations 49
# Cbc0038I Pass  21: suminf.    0.96348 (2) obj. 666.297 iterations 30
# Cbc0038I Pass  22: suminf.    1.32602 (5) obj. 666.741 iterations 104
# Cbc0038I Pass  23: suminf.    0.71516 (2) obj. 672.434 iterations 26
# Cbc0038I Pass  24: suminf.    0.48717 (1) obj. 676.966 iterations 17
# Cbc0038I Pass  25: suminf.    0.35758 (1) obj. 676.966 iterations 12
# Cbc0038I Pass  26: suminf.    0.42293 (1) obj. 629.49 iterations 87
# Cbc0038I Pass  27: suminf.    0.29334 (1) obj. 629.49 iterations 40
# Cbc0038I Pass  28: suminf.    0.42293 (1) obj. 629.49 iterations 18
# Cbc0038I Pass  29: suminf.    0.74037 (2) obj. 633.378 iterations 95
# Cbc0038I Pass  30: suminf.    0.24060 (1) obj. 636.42 iterations 31
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 445 rows 321 columns, reduced to 445 rows 289 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I Full problem 446 rows 321 columns, reduced to 446 rows 321 columns - too large
# Cbc0038I After 0.10 seconds - Feasibility pump exiting - took 0.03 seconds
# Cbc0031I 34 added rows had average density of 191.47059
# Cbc0013I At root node, 34 cuts changed objective from 0 to 21.146974 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (23 active)  in 0.040 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 2382 row cuts average 298.4 elements, 0 column cuts (0 active)  in 0.291 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.049 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.457 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 50 row cuts average 220.0 elements, 0 column cuts (0 active)  in 0.155 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 21.146974 (4.00 seconds)
# Cbc0012I Integer solution of 32.740917 found by DiveCoefficient after 9035 iterations and 1 nodes (4.04 seconds)
# Cbc0012I Integer solution of 32.740917 found by heuristic after 8894 iterations and 0 nodes (4.19 seconds)
# Cbc0030I Thread 0 used 12 times,  waiting to start 0.37435341, 1.202718 cpu time, 65 locks, 0.001054287 locked, 0.00040268898 waiting for locks
# Cbc0030I Thread 1 used 6 times,  waiting to start 0.99641919, 0.683686 cpu time, 33 locks, 0.00036287308 locked, 8.4161758e-05 waiting for locks
# Cbc0030I Thread 2 used 6 times,  waiting to start 1.3203478, 0.091318 cpu time, 24 locks, 0.00073766708 locked, 0.00032925606 waiting for locks
# Cbc0030I Thread 3 used 0 times,  waiting to start 1.319154, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 4 used 0 times,  waiting to start 1.237561, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 5 used 0 times,  waiting to start 1.1694701, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Main thread 0.51698637 waiting for threads,  53 locks, 5.531311e-05 locked, 0.00026011467 waiting for locks
# Cbc0001I Search completed - best objective 32.740917191841, took 11884 iterations and 24 nodes (5.52 seconds)
# Cbc0032I Strong branching done 1634 times (119780 iterations), fathomed 2 nodes and fixed 3 variables
# Cbc0035I Maximum depth 10, 246 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 21.147
# Probing was tried 700 times and created 0 cuts of which 161 were active after adding rounds of cuts (0.277 seconds)
# Gomory was tried 700 times and created 16674 cuts of which 0 were active after adding rounds of cuts (2.035 seconds)
# Knapsack was tried 700 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.341 seconds)
# Clique was tried 700 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.049 seconds)
# MixedIntegerRounding2 was tried 700 times and created 0 cuts of which 0 were active after adding rounds of cuts (3.198 seconds)
# FlowCover was tried 700 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.046 seconds)
# TwoMirCuts was tried 700 times and created 350 cuts of which 0 were active after adding rounds of cuts (1.083 seconds)
# ZeroHalf was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
#
# Result - Optimal solution found
#
# Objective value:                32.74091719
# Enumerated nodes:               24
# Total iterations:               11884
# Time (CPU seconds):             4.71
# Time (Wallclock seconds):       5.58
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       4.71   (Wallclock seconds):       5.59
#
# 1
# xVanBuren 1.0
# xDesMoines 1.0
# xHenry 1.0
# xLee 1.0
# xLouisa 1.0
# Sending to solver...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/z3/3qb7cv41693fmz3b6hbntjkr0000gn/T/3dfbc62336644261a64ba1b63039cc41-pulp.mps -threads 6 -timeMode elapsed -branch -printingOptions all -solution /var/folders/z3/3qb7cv41693fmz3b6hbntjkr0000gn/T/3dfbc62336644261a64ba1b63039cc41-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 517 COLUMNS
# At line 2766 RHS
# At line 3279 BOUNDS
# At line 3582 ENDATA
# Problem MODEL has 512 rows, 302 columns and 1436 elements
# Coin0008I MODEL read with 0 errors
# threads was changed from 0 to 6
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 417 rows, 302 columns (302 integer (302 of which binary)) and 1342 elements
# Cbc0038I Initial state - 94 integers unsatisfied sum - 18.7849
# Cbc0038I Pass   1: suminf.    2.56457 (6) obj. 42.3469 iterations 115
# Cbc0038I Pass   2: suminf.    1.97602 (4) obj. 46.4592 iterations 17
# Cbc0038I Pass   3: suminf.    0.10707 (1) obj. 55.5361 iterations 49
# Cbc0038I Pass   4: suminf.    0.23666 (1) obj. 55.5361 iterations 17
# Cbc0038I Pass   5: suminf.    1.64847 (5) obj. 242.227 iterations 107
# Cbc0038I Pass   6: suminf.    0.42007 (2) obj. 247.97 iterations 89
# Cbc0038I Pass   7: suminf.    0.33962 (1) obj. 250.663 iterations 26
# Cbc0038I Pass   8: suminf.    0.21004 (1) obj. 250.663 iterations 23
# Cbc0038I Pass   9: suminf.    0.27386 (1) obj. 340.7 iterations 106
# Cbc0038I Pass  10: suminf.    0.27386 (1) obj. 340.7 iterations 33
# Cbc0038I Pass  11: suminf.    0.39155 (2) obj. 340.7 iterations 39
# Cbc0038I Pass  12: suminf.    0.63312 (2) obj. 340.7 iterations 29
# Cbc0038I Pass  13: suminf.    0.33962 (1) obj. 373.445 iterations 90
# Cbc0038I Pass  14: suminf.    0.21004 (1) obj. 373.445 iterations 57
# Cbc0038I Pass  15: suminf.    0.33962 (1) obj. 373.445 iterations 20
# Cbc0038I Pass  16: suminf.    0.70938 (2) obj. 434.797 iterations 90
# Cbc0038I Pass  17: suminf.    0.35469 (1) obj. 437.957 iterations 77
# Cbc0038I Pass  18: suminf.    0.48427 (1) obj. 437.957 iterations 20
# Cbc0038I Pass  19: suminf.    1.29664 (3) obj. 537.133 iterations 85
# Cbc0038I Pass  20: suminf.    0.86442 (2) obj. 538.606 iterations 39
# Cbc0038I Pass  21: suminf.    0.87947 (2) obj. 538.606 iterations 36
# Cbc0038I Pass  22: suminf.    0.90027 (2) obj. 603.44 iterations 95
# Cbc0038I Solution found of 602.242
# Cbc0038I Before mini branch and bound, 64 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 417 rows 302 columns, reduced to 417 rows 238 columns - 37 fixed gives 342, 201 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of 542.018
# Cbc0038I Pass  23: suminf.    2.56457 (6) obj. 42.3469 iterations 0
# Cbc0038I Pass  24: suminf.    1.97602 (4) obj. 46.4592 iterations 14
# Cbc0038I Pass  25: suminf.    0.10707 (1) obj. 55.5361 iterations 56
# Cbc0038I Pass  26: suminf.    0.23666 (1) obj. 55.5361 iterations 19
# Cbc0038I Pass  27: suminf.    0.25490 (2) obj. 329.408 iterations 116
# Cbc0038I Pass  28: suminf.    0.12745 (1) obj. 330.311 iterations 51
# Cbc0038I Pass  29: suminf.    0.25703 (1) obj. 330.311 iterations 15
# Cbc0038I Pass  30: suminf.    0.18356 (3) obj. 485.119 iterations 90
# Cbc0038I Pass  31: suminf.    0.18356 (3) obj. 485.119 iterations 32
# Cbc0038I Pass  32: suminf.    0.30950 (1) obj. 496.343 iterations 45
# Cbc0038I Pass  33: suminf.    0.43909 (1) obj. 496.343 iterations 22
# Cbc0038I Pass  34: suminf.    1.24597 (6) obj. 536.606 iterations 111
# Cbc0038I Solution found of 541.451
# Cbc0038I Rounding solution of 173.712 is better than previous of 541.451
#
# Cbc0038I Before mini branch and bound, 92 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 417 rows 302 columns, reduced to 417 rows 210 columns - 48 fixed gives 321, 162 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I Round again with cutoff of 138.97
# Cbc0038I Pass  35: suminf.    2.56457 (6) obj. 42.3469 iterations 0
# Cbc0038I Pass  36: suminf.    1.97602 (4) obj. 46.4592 iterations 14
# Cbc0038I Pass  37: suminf.    0.10707 (1) obj. 55.5361 iterations 57
# Cbc0038I Pass  38: suminf.    0.23666 (1) obj. 55.5361 iterations 21
# Cbc0038I Pass  39: suminf.    1.95066 (4) obj. 138.97 iterations 115
# Cbc0038I Pass  40: suminf.    1.95066 (4) obj. 138.97 iterations 35
# Cbc0038I Pass  41: suminf.    1.71373 (4) obj. 138.97 iterations 87
# Cbc0038I Pass  42: suminf.    1.71373 (4) obj. 138.97 iterations 21
# Cbc0038I Pass  43: suminf.    0.39908 (4) obj. 138.97 iterations 126
# Cbc0038I Pass  44: suminf.    0.94663 (4) obj. 135.197 iterations 15
# Cbc0038I Pass  45: suminf.    1.46397 (6) obj. 138.97 iterations 78
# Cbc0038I Pass  46: suminf.    0.96450 (5) obj. 138.97 iterations 91
# Cbc0038I Pass  47: suminf.    1.18328 (5) obj. 137.474 iterations 36
# Cbc0038I Pass  48: suminf.    1.50524 (6) obj. 138.97 iterations 84
# Cbc0038I Pass  49: suminf.    0.95934 (5) obj. 138.97 iterations 103
# Cbc0038I Pass  50: suminf.    1.18328 (5) obj. 137.438 iterations 32
# Cbc0038I Pass  51: suminf.    1.89630 (10) obj. 138.97 iterations 95
# Cbc0038I Pass  52: suminf.    1.67651 (9) obj. 138.97 iterations 124
# Cbc0038I Pass  53: suminf.    2.13714 (5) obj. 138.876 iterations 41
# Cbc0038I Pass  54: suminf.    2.12396 (5) obj. 138.97 iterations 59
# Cbc0038I Pass  55: suminf.    0.82790 (8) obj. 138.97 iterations 88
# Cbc0038I Pass  56: suminf.    2.25523 (10) obj. 138.97 iterations 80
# Cbc0038I Pass  57: suminf.    1.31795 (8) obj. 138.97 iterations 87
# Cbc0038I Pass  58: suminf.    2.07474 (9) obj. 138.97 iterations 25
# Cbc0038I Pass  59: suminf.    1.78808 (5) obj. 138.97 iterations 93
# Cbc0038I Pass  60: suminf.    1.33662 (4) obj. 138.97 iterations 37
# Cbc0038I Pass  61: suminf.    1.01473 (3) obj. 137.497 iterations 60
# Cbc0038I Pass  62: suminf.    1.52923 (6) obj. 138.97 iterations 83
# Cbc0038I Pass  63: suminf.    1.44245 (5) obj. 134.709 iterations 34
# Cbc0038I Pass  64: suminf.    0.72780 (5) obj. 138.97 iterations 29
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 137 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 417 rows 302 columns, reduced to 417 rows 165 columns - 15 fixed gives 387, 150 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.10 seconds)
# Cbc0038I After 0.10 seconds - Feasibility pump exiting with objective of 173.712 - took 0.08 seconds
# Cbc0012I Integer solution of 173.71192 found by feasibility pump after 0 iterations and 0 nodes (0.10 seconds)
# Cbc0012I Integer solution of 45.551941 found by DiveCoefficient after 0 iterations and 0 nodes (0.12 seconds)
# Cbc0038I Full problem 417 rows 302 columns, reduced to 417 rows 105 columns - 1 fixed gives 415, 104 - still too large
# Cbc0031I 32 added rows had average density of 213.4375
# Cbc0013I At root node, 32 cuts changed objective from 0 to 20.985666 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (16 active)  in 0.038 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 2256 row cuts average 283.9 elements, 0 column cuts (0 active)  in 0.275 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.050 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 110.0 elements, 0 column cuts (0 active)  in 0.395 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 47 row cuts average 222.4 elements, 0 column cuts (0 active)  in 0.121 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 45.551941 best solution, best possible 20.985666 (3.79 seconds)
# Cbc0012I Integer solution of 41.293189 found by rounding after 12846 iterations and 28 nodes (4.88 seconds)
# Cbc0012I Integer solution of 41.293189 found by heuristic after 12758 iterations and 27 nodes (4.88 seconds)
# Cbc0030I Thread 0 used 15 times,  waiting to start 0.42347002,  83 locks, 0.0018861294 locked, 8.4877014e-05 waiting for locks
# Cbc0030I Thread 1 used 10 times,  waiting to start 0.95995617,  50 locks, 0.0015830994 locked, 0.00016379356 waiting for locks
# Cbc0030I Thread 2 used 9 times,  waiting to start 0.9006443,  46 locks, 0.002862215 locked, 0.0028953552 waiting for locks
# Cbc0030I Thread 3 used 6 times,  waiting to start 0.97969699,  33 locks, 0.0002913475 locked, 0.00095677376 waiting for locks
# Cbc0030I Thread 4 used 4 times,  waiting to start 0.97162557,  22 locks, 0.00025272369 locked, 0.0025997162 waiting for locks
# Cbc0030I Thread 5 used 0 times,  waiting to start 1.2480311,  0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Main thread 0.56928253 waiting for threads,  95 locks, 5.9604645e-05 locked, 0.0017149448 waiting for locks
# Cbc0001I Search completed - best objective 41.293189019992, took 14314 iterations and 44 nodes (5.35 seconds)
# Cbc0032I Strong branching done 1996 times (135684 iterations), fathomed 8 nodes and fixed 13 variables
# Cbc0035I Maximum depth 9, 517 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 20.9857
# Probing was tried 700 times and created 0 cuts of which 112 were active after adding rounds of cuts (0.266 seconds)
# Gomory was tried 700 times and created 15792 cuts of which 0 were active after adding rounds of cuts (1.924 seconds)
# Knapsack was tried 700 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.349 seconds)
# Clique was tried 700 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.047 seconds)
# MixedIntegerRounding2 was tried 700 times and created 7 cuts of which 0 were active after adding rounds of cuts (2.767 seconds)
# FlowCover was tried 700 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.042 seconds)
# TwoMirCuts was tried 700 times and created 329 cuts of which 0 were active after adding rounds of cuts (0.846 seconds)
# ZeroHalf was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# ImplicationCuts was tried 41 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                41.29318902
# Enumerated nodes:               44
# Total iterations:               14314
# Time (CPU seconds):             5.81
# Time (Wallclock seconds):       5.40
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       5.82   (Wallclock seconds):       5.40
#
# 1
# xAllamakee 1.0
# xClayton 1.0
# xWinneshiek 1.0
# xBenton 1.0
# xBlackHawk 1.0
# xBuchanan 1.0
# xLinn 1.0
# xTama 1.0
# xBremer 1.0
# xButler 1.0
# xGrundy 1.0
# xChickasaw 1.0
# xFayette 1.0
# xDelaware 1.0
# xFloyd 1.0
# xCedar 1.0
# xClinton 1.0
# xJohnson 1.0
# xJones 1.0
# xMuscatine 1.0
# xScott 1.0
# xHoward 1.0
# xDubuque 1.0
# xJackson 1.0
# Sending to solver...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/z3/3qb7cv41693fmz3b6hbntjkr0000gn/T/30ae2bef50944e89af67a0b9b0aad658-pulp.mps -threads 6 -timeMode elapsed -branch -printingOptions all -solution /var/folders/z3/3qb7cv41693fmz3b6hbntjkr0000gn/T/30ae2bef50944e89af67a0b9b0aad658-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 375 COLUMNS
# At line 1997 RHS
# At line 2368 BOUNDS
# At line 2588 ENDATA
# Problem MODEL has 370 rows, 219 columns and 1034 elements
# Coin0008I MODEL read with 0 errors
# threads was changed from 0 to 6
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 299 rows, 219 columns (219 integer (219 of which binary)) and 964 elements
# Cbc0038I Initial state - 70 integers unsatisfied sum - 23.319
# Cbc0038I Pass   1: suminf.    3.23377 (12) obj. 60.318 iterations 105
# Cbc0038I Pass   2: suminf.    2.44759 (65) obj. 56.2595 iterations 55
# Cbc0038I Pass   3: suminf.    2.91716 (7) obj. 75.3398 iterations 85
# Cbc0038I Solution found of 88.9725
# Cbc0038I Rounding solution of 80.6262 is better than previous of 88.9725
#
# Cbc0038I Before mini branch and bound, 132 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 299 rows 219 columns, reduced to 299 rows 87 columns - 3 fixed gives 286, 82 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 72.5636
# Cbc0038I Pass   4: suminf.    3.23377 (12) obj. 60.318 iterations 0
# Cbc0038I Pass   5: suminf.    2.44759 (65) obj. 56.2595 iterations 60
# Cbc0038I Pass   6: suminf.    7.53955 (16) obj. 72.5636 iterations 115
# Cbc0038I Pass   7: suminf.   11.28620 (66) obj. 72.5636 iterations 86
# Cbc0038I Pass   8: suminf.    8.45513 (68) obj. 72.5636 iterations 54
# Cbc0038I Pass   9: suminf.    8.45513 (68) obj. 72.5636 iterations 0
# Cbc0038I Pass  10: suminf.    9.67888 (76) obj. 72.5636 iterations 59
# Cbc0038I Pass  11: suminf.    0.79337 (68) obj. 72.5636 iterations 60
# Cbc0038I Pass  12: suminf.    0.24398 (61) obj. 72.5636 iterations 81
# Cbc0038I Pass  13: suminf.    0.31129 (6) obj. 72.5636 iterations 67
# Cbc0038I Pass  14: suminf.    1.71153 (68) obj. 72.5636 iterations 108
# Cbc0038I Pass  15: suminf.    0.43065 (68) obj. 72.5636 iterations 20
# Cbc0038I Pass  16: suminf.    0.43065 (68) obj. 72.5636 iterations 2
# Cbc0038I Pass  17: suminf.    0.55817 (3) obj. 71.2407 iterations 70
# Cbc0038I Pass  18: suminf.    0.23802 (5) obj. 72.1916 iterations 87
# Cbc0038I Pass  19: suminf.    0.42388 (6) obj. 72.5636 iterations 39
# Cbc0038I Pass  20: suminf.    8.76993 (68) obj. 72.5636 iterations 94
# Cbc0038I Pass  21: suminf.    8.76993 (68) obj. 72.5636 iterations 34
# Cbc0038I Pass  22: suminf.    0.43976 (77) obj. 72.5636 iterations 51
# Cbc0038I Pass  23: suminf.    0.41918 (68) obj. 72.5636 iterations 33
# Cbc0038I Pass  24: suminf.    1.77049 (62) obj. 72.5636 iterations 139
# Cbc0038I Pass  25: suminf.    0.69470 (5) obj. 72.5636 iterations 64
# Cbc0038I Pass  26: suminf.    0.81472 (6) obj. 72.5636 iterations 67
# Cbc0038I Pass  27: suminf.    8.85169 (78) obj. 72.5636 iterations 89
# Cbc0038I Pass  28: suminf.    2.15857 (69) obj. 72.5636 iterations 28
# Cbc0038I Pass  29: suminf.    2.15857 (69) obj. 72.5636 iterations 7
# Cbc0038I Pass  30: suminf.    2.96792 (67) obj. 72.5636 iterations 60
# Cbc0038I Pass  31: suminf.    0.90854 (69) obj. 72.5636 iterations 59
# Cbc0038I Pass  32: suminf.    0.90854 (69) obj. 72.5636 iterations 0
# Cbc0038I Pass  33: suminf.    2.49053 (13) obj. 72.5636 iterations 105
# Cbc0038I Rounding solution of 69.4388 is better than previous of 80.6262
#
# Cbc0038I Before mini branch and bound, 103 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 299 rows 219 columns, reduced to 299 rows 116 columns - 3 fixed gives 289, 112 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I Round again with cutoff of 55.5511
# Cbc0038I Pass  33: suminf.    2.85953 (78) obj. 55.5511 iterations 13
# Cbc0038I Pass  34: suminf.    2.52381 (68) obj. 55.5511 iterations 73
# Cbc0038I Pass  35: suminf.    2.52381 (68) obj. 55.5511 iterations 62
# Cbc0038I Pass  36: suminf.   10.06131 (74) obj. 55.5511 iterations 87
# Cbc0038I Pass  37: suminf.    9.38202 (72) obj. 55.5511 iterations 56
# Cbc0038I Pass  38: suminf.    2.17792 (72) obj. 55.5511 iterations 48
# Cbc0038I Pass  39: suminf.    2.17792 (72) obj. 55.5511 iterations 34
# Cbc0038I Pass  40: suminf.    1.93091 (65) obj. 54.5549 iterations 125
# Cbc0038I Pass  41: suminf.    1.90120 (64) obj. 54.69 iterations 73
# Cbc0038I Pass  42: suminf.    2.31930 (82) obj. 55.5511 iterations 73
# Cbc0038I Pass  43: suminf.    6.05956 (74) obj. 55.5511 iterations 79
# Cbc0038I Pass  44: suminf.    2.40804 (72) obj. 55.5511 iterations 41
# Cbc0038I Pass  45: suminf.    1.95808 (66) obj. 55.5511 iterations 33
# Cbc0038I Pass  46: suminf.    2.05758 (76) obj. 55.5511 iterations 66
# Cbc0038I Pass  47: suminf.    7.88987 (74) obj. 55.5511 iterations 78
# Cbc0038I Pass  48: suminf.    2.14220 (73) obj. 55.5511 iterations 28
# Cbc0038I Pass  49: suminf.    2.14220 (73) obj. 55.5511 iterations 5
# Cbc0038I Pass  50: suminf.    2.18042 (72) obj. 55.5511 iterations 47
# Cbc0038I Pass  51: suminf.    3.12793 (70) obj. 55.5511 iterations 57
# Cbc0038I Pass  52: suminf.    1.90354 (6) obj. 55.5511 iterations 47
# Cbc0038I Pass  53: suminf.    1.90354 (6) obj. 55.5511 iterations 0
# Cbc0038I Pass  54: suminf.    2.14736 (6) obj. 55.5511 iterations 89
# Cbc0038I Pass  55: suminf.    1.51041 (5) obj. 55.5511 iterations 33
# Cbc0038I Pass  56: suminf.    1.20378 (4) obj. 55.5511 iterations 18
# Cbc0038I Pass  57: suminf.    1.38876 (4) obj. 54.8478 iterations 37
# Cbc0038I Pass  58: suminf.    8.53776 (69) obj. 55.5511 iterations 93
# Cbc0038I Pass  59: suminf.    8.16793 (67) obj. 55.5511 iterations 43
# Cbc0038I Pass  60: suminf.   12.44771 (74) obj. 55.5511 iterations 48
# Cbc0038I Pass  61: suminf.    2.94729 (68) obj. 55.5511 iterations 67
# Cbc0038I Pass  62: suminf.    0.70025 (71) obj. 55.5511 iterations 23
# Cbc0038I Rounding solution of 53.9522 is better than previous of 69.4388
#
# Cbc0038I Before mini branch and bound, 88 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 299 rows 219 columns, reduced to 299 rows 131 columns - 3 fixed gives 248, 115 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.09 seconds)
# Cbc0038I Round again with cutoff of 37.7665
# Cbc0038I Pass  62: suminf.    8.43863 (74) obj. 37.7665 iterations 21
# Cbc0038I Pass  63: suminf.    8.43863 (74) obj. 37.7665 iterations 25
# Cbc0038I Pass  64: suminf.    8.38809 (73) obj. 37.7665 iterations 31
# Cbc0038I Pass  65: suminf.    8.36273 (72) obj. 37.7665 iterations 33
# Cbc0038I Pass  66: suminf.    9.71349 (74) obj. 37.7665 iterations 37
# Cbc0038I Pass  67: suminf.    8.43863 (74) obj. 37.7665 iterations 36
# Cbc0038I Pass  68: suminf.    8.43863 (74) obj. 37.7665 iterations 24
# Cbc0038I Pass  69: suminf.    9.77115 (70) obj. 37.7665 iterations 63
# Cbc0038I Pass  70: suminf.    8.38809 (73) obj. 37.7665 iterations 61
# Cbc0038I Pass  71: suminf.    8.36273 (72) obj. 37.7665 iterations 4
# Cbc0038I Pass  72: suminf.    9.71349 (74) obj. 37.7665 iterations 52
# Cbc0038I Pass  73: suminf.    8.43863 (74) obj. 37.7665 iterations 36
# Cbc0038I Pass  74: suminf.    8.43863 (74) obj. 37.7665 iterations 19
# Cbc0038I Pass  75: suminf.    8.38809 (73) obj. 37.7665 iterations 47
# Cbc0038I Pass  76: suminf.    8.36273 (72) obj. 37.7665 iterations 48
# Cbc0038I Pass  77: suminf.    9.27791 (75) obj. 37.7665 iterations 46
# Cbc0038I Pass  78: suminf.    8.43863 (74) obj. 37.7665 iterations 36
# Cbc0038I Pass  79: suminf.    8.43863 (74) obj. 37.7665 iterations 21
# Cbc0038I Pass  80: suminf.    8.36273 (72) obj. 37.7665 iterations 26
# Cbc0038I Pass  81: suminf.    8.36273 (72) obj. 37.7665 iterations 26
# Cbc0038I Pass  82: suminf.    9.27791 (75) obj. 37.7665 iterations 32
# Cbc0038I Pass  83: suminf.    8.43863 (74) obj. 37.7665 iterations 21
# Cbc0038I Pass  84: suminf.    8.43863 (74) obj. 37.7665 iterations 17
# Cbc0038I Pass  85: suminf.    8.38809 (73) obj. 37.7665 iterations 19
# Cbc0038I Pass  86: suminf.    8.36273 (72) obj. 37.7665 iterations 25
# Cbc0038I Pass  87: suminf.    9.27791 (75) obj. 37.7665 iterations 39
# Cbc0038I Pass  88: suminf.    8.43863 (74) obj. 37.7665 iterations 23
# Cbc0038I Pass  89: suminf.    8.43863 (74) obj. 37.7665 iterations 23
# Cbc0038I Pass  90: suminf.    9.31095 (74) obj. 37.7665 iterations 63
# Cbc0038I Pass  91: suminf.    8.35580 (70) obj. 37.7665 iterations 53
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 138 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.12 seconds)
# Cbc0038I After 0.12 seconds - Feasibility pump exiting with objective of 53.9522 - took 0.10 seconds
# Cbc0012I Integer solution of 53.952187 found by feasibility pump after 0 iterations and 0 nodes (0.12 seconds)
# Cbc0038I Full problem 299 rows 219 columns, reduced to 299 rows 82 columns - 12 fixed gives 260, 67 - still too large
# Cbc0031I 22 added rows had average density of 159.86364
# Cbc0013I At root node, 22 cuts changed objective from 0 to 19.374851 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (1 active)  in 0.032 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1991 row cuts average 210.9 elements, 0 column cuts (0 active)  in 0.159 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.038 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.217 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 53 row cuts average 169.3 elements, 0 column cuts (0 active)  in 0.104 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 53.952187 best solution, best possible 19.374851 (2.08 seconds)
# Cbc0012I Integer solution of 40.29538 found by DiveCoefficient after 7296 iterations and 1 nodes (2.20 seconds)
# Cbc0012I Integer solution of 40.29538 found by heuristic after 7120 iterations and 0 nodes (2.20 seconds)
# Cbc0030I Thread 0 used 10 times,  waiting to start 0.25836849, 0.547428 cpu time, 53 locks, 0.00067877769 locked, 6.6757202e-06 waiting for locks
# Cbc0030I Thread 1 used 4 times,  waiting to start 0.41790509, 0.357547 cpu time, 19 locks, 7.891655e-05 locked, 1.5735626e-05 waiting for locks
# Cbc0030I Thread 2 used 2 times,  waiting to start 0.50802875, 0.09413 cpu time, 9 locks, 4.4107437e-05 locked, 4.7683716e-06 waiting for locks
# Cbc0030I Thread 3 used 0 times,  waiting to start 0.49826789, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 4 used 0 times,  waiting to start 0.43952799, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 5 used 0 times,  waiting to start 0.39386582, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Main thread 0.3252399 waiting for threads,  37 locks, 3.6716461e-05 locked, 9.1075897e-05 waiting for locks
# Cbc0001I Search completed - best objective 40.295380327433, took 8821 iterations and 16 nodes (2.70 seconds)
# Cbc0032I Strong branching done 1586 times (85318 iterations), fathomed 7 nodes and fixed 1 variables
# Cbc0035I Maximum depth 5, 169 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 19.3749
# Probing was tried 700 times and created 0 cuts of which 7 were active after adding rounds of cuts (0.223 seconds)
# Gomory was tried 700 times and created 13937 cuts of which 0 were active after adding rounds of cuts (1.111 seconds)
# Knapsack was tried 700 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.264 seconds)
# Clique was tried 700 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.035 seconds)
# MixedIntegerRounding2 was tried 700 times and created 0 cuts of which 0 were active after adding rounds of cuts (1.518 seconds)
# FlowCover was tried 700 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.031 seconds)
# TwoMirCuts was tried 700 times and created 371 cuts of which 0 were active after adding rounds of cuts (0.725 seconds)
# ZeroHalf was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
#
# Result - Optimal solution found
#
# Objective value:                40.29538033
# Enumerated nodes:               16
# Total iterations:               8821
# Time (CPU seconds):             2.67
# Time (Wallclock seconds):       2.74
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.67   (Wallclock seconds):       2.75
#
# 1
# xAdams 1.0
# xCass 1.0
# xUnion 1.0
# xMontgomery 1.0
# xTaylor 1.0
# xShelby 1.0
# xCrawford 1.0
# xPottawattamie 1.0
# xHarrison 1.0
# xMonona 1.0
# xRinggold 1.0
# xFremont 1.0
# xMills 1.0
# xPage 1.0
# Sending to solver...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/z3/3qb7cv41693fmz3b6hbntjkr0000gn/T/fa1626c19d32435fa6a134c184d59780-pulp.mps -threads 6 -timeMode elapsed -branch -printingOptions all -solution /var/folders/z3/3qb7cv41693fmz3b6hbntjkr0000gn/T/fa1626c19d32435fa6a134c184d59780-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 291 COLUMNS
# At line 1542 RHS
# At line 1829 BOUNDS
# At line 2000 ENDATA
# Problem MODEL has 286 rows, 170 columns and 796 elements
# Coin0008I MODEL read with 0 errors
# threads was changed from 0 to 6
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 229 rows, 170 columns (170 integer (170 of which binary)) and 740 elements
# Cbc0038I Initial state - 56 integers unsatisfied sum - 25.1313
# Cbc0038I Pass   1: suminf.   20.12427 (60) obj. 25.9542 iterations 50
# Cbc0038I Pass   2: suminf.    3.82629 (59) obj. 89.8183 iterations 32
# Cbc0038I Pass   3: suminf.    3.17777 (49) obj. 93.3389 iterations 59
# Cbc0038I Pass   4: suminf.    0.45121 (1) obj. 121.993 iterations 74
# Cbc0038I Pass   5: suminf.    0.45121 (1) obj. 121.993 iterations 25
# Cbc0038I Pass   6: suminf.    0.13135 (1) obj. 121.993 iterations 22
# Cbc0038I Pass   7: suminf.    0.70234 (7) obj. 240.727 iterations 102
# Cbc0038I Pass   8: suminf.    0.15725 (5) obj. 241.653 iterations 33
# Cbc0038I Pass   9: suminf.    0.44889 (1) obj. 261.554 iterations 36
# Cbc0038I Pass  10: suminf.    0.03145 (1) obj. 261.554 iterations 16
# Cbc0038I Pass  11: suminf.    0.55686 (2) obj. 281.686 iterations 40
# Cbc0038I Pass  12: suminf.    0.02731 (2) obj. 281.159 iterations 17
# Cbc0038I Pass  13: suminf.    0.43109 (1) obj. 290.265 iterations 16
# Cbc0038I Pass  14: suminf.    0.01365 (1) obj. 290.265 iterations 13
# Cbc0038I Pass  15: suminf.    0.07836 (1) obj. 325.85 iterations 44
# Cbc0038I Solution found of 325.85
# Cbc0038I Rounding solution of 75.2949 is better than previous of 325.85
#
# Cbc0038I Before mini branch and bound, 44 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 229 rows 170 columns, reduced to 229 rows 126 columns - 20 fixed gives 173, 101 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I Round again with cutoff of 67.7654
# Cbc0038I Pass  16: suminf.   20.12427 (60) obj. 25.9542 iterations 0
# Cbc0038I Pass  17: suminf.   11.12175 (60) obj. 67.7654 iterations 28
# Cbc0038I Pass  18: suminf.   10.58539 (56) obj. 67.7654 iterations 25
# Cbc0038I Pass  19: suminf.    6.60445 (36) obj. 67.7654 iterations 76
# Cbc0038I Pass  20: suminf.    2.10202 (8) obj. 67.7654 iterations 49
# Cbc0038I Pass  21: suminf.    0.63991 (3) obj. 63.6452 iterations 36
# Cbc0038I Pass  22: suminf.    1.48316 (3) obj. 67.7654 iterations 26
# Cbc0038I Pass  23: suminf.    1.51047 (34) obj. 67.7654 iterations 40
# Cbc0038I Pass  24: suminf.    1.17924 (30) obj. 67.7654 iterations 40
# Cbc0038I Pass  25: suminf.    6.36401 (33) obj. 67.7654 iterations 61
# Cbc0038I Pass  26: suminf.    1.62985 (34) obj. 67.7654 iterations 65
# Cbc0038I Pass  27: suminf.    1.13129 (29) obj. 67.7654 iterations 49
# Cbc0038I Pass  28: suminf.    4.93663 (36) obj. 67.7654 iterations 39
# Cbc0038I Pass  29: suminf.    3.60068 (34) obj. 67.7654 iterations 62
# Cbc0038I Pass  30: suminf.    1.44653 (34) obj. 67.7654 iterations 29
# Cbc0038I Pass  31: suminf.    1.21876 (31) obj. 67.7654 iterations 22
# Cbc0038I Pass  32: suminf.    1.18499 (4) obj. 63.2197 iterations 39
# Cbc0038I Solution found of 66.0043
# Cbc0038I Rounding solution of 39.2088 is better than previous of 66.0043
#
# Cbc0038I Before mini branch and bound, 71 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 229 rows 170 columns, reduced to 229 rows 99 columns - 16 fixed gives 151, 69 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of 31.367
# Cbc0038I Pass  33: suminf.   20.12427 (60) obj. 25.9542 iterations 0
# Cbc0038I Pass  34: suminf.   19.05254 (57) obj. 31.367 iterations 39
# Cbc0038I Pass  35: suminf.   20.85156 (64) obj. 31.367 iterations 55
# Cbc0038I Pass  36: suminf.   28.15215 (57) obj. 31.367 iterations 104
# Cbc0038I Pass  37: suminf.   24.69255 (58) obj. 31.367 iterations 45
# Cbc0038I Pass  38: suminf.   21.62690 (57) obj. 31.367 iterations 5
# Cbc0038I Pass  39: suminf.   21.62690 (57) obj. 31.367 iterations 11
# Cbc0038I Pass  40: suminf.   21.62690 (57) obj. 31.367 iterations 36
# Cbc0038I Pass  41: suminf.   25.56657 (57) obj. 31.367 iterations 49
# Cbc0038I Pass  42: suminf.   25.56657 (57) obj. 31.367 iterations 21
# Cbc0038I Pass  43: suminf.   25.56657 (57) obj. 31.367 iterations 47
# Cbc0038I Pass  44: suminf.   27.80426 (57) obj. 31.367 iterations 52
# Cbc0038I Pass  45: suminf.   25.15887 (57) obj. 31.367 iterations 27
# Cbc0038I Pass  46: suminf.   25.15887 (57) obj. 31.367 iterations 26
# Cbc0038I Pass  47: suminf.   28.12927 (57) obj. 31.367 iterations 35
# Cbc0038I Pass  48: suminf.   25.48388 (57) obj. 31.367 iterations 31
# Cbc0038I Pass  49: suminf.   11.62982 (64) obj. 31.367 iterations 54
# Cbc0038I Pass  50: suminf.    4.47774 (65) obj. 31.367 iterations 23
# Cbc0038I Pass  51: suminf.    4.47774 (65) obj. 31.367 iterations 4
# Cbc0038I Pass  52: suminf.    8.10040 (42) obj. 30.7409 iterations 58
# Cbc0038I Pass  53: suminf.    6.96626 (64) obj. 31.367 iterations 68
# Cbc0038I Pass  54: suminf.    5.03850 (49) obj. 31.367 iterations 47
# Cbc0038I Pass  55: suminf.    3.00429 (37) obj. 31.367 iterations 60
# Cbc0038I Pass  56: suminf.   20.79782 (55) obj. 31.367 iterations 49
# Cbc0038I Pass  57: suminf.   20.44769 (54) obj. 31.367 iterations 23
# Cbc0038I Pass  58: suminf.    7.91822 (37) obj. 31.367 iterations 37
# Cbc0038I Pass  59: suminf.    9.24376 (61) obj. 31.367 iterations 31
# Cbc0038I Pass  60: suminf.    3.74635 (43) obj. 31.367 iterations 35
# Cbc0038I Pass  61: suminf.    3.30091 (40) obj. 31.367 iterations 31
# Cbc0038I Pass  62: suminf.    3.30091 (40) obj. 31.367 iterations 22
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 65 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 229 rows 170 columns, reduced to 229 rows 105 columns - 12 fixed gives 119, 60 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I After 0.07 seconds - Feasibility pump exiting with objective of 39.2088 - took 0.06 seconds
# Cbc0012I Integer solution of 39.208791 found by feasibility pump after 0 iterations and 0 nodes (0.07 seconds)
# Cbc0038I Full problem 229 rows 170 columns, reduced to 229 rows 66 columns - 12 fixed gives 142, 39 - still too large
# Cbc0031I 18 added rows had average density of 136.05556
# Cbc0013I At root node, 18 cuts changed objective from 0 to 16.353548 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (4 active)  in 0.026 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1729 row cuts average 166.8 elements, 0 column cuts (0 active)  in 0.117 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.028 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.177 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 51 row cuts average 124.9 elements, 0 column cuts (0 active)  in 0.067 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 39.208791 best solution, best possible 16.353548 (1.30 seconds)
# Cbc0012I Integer solution of 34.868713 found by DiveCoefficient after 6216 iterations and 2 nodes (1.36 seconds)
# Cbc0012I Integer solution of 34.868713 found by heuristic after 6327 iterations and 3 nodes (1.39 seconds)
# Cbc0016I Integer solution of 32.562159 found by strong branching after 6691 iterations and 5 nodes (1.42 seconds)
# Clp0006I 0  Obj 32.304081 Primal inf 2.4422423 (1)
# Cbc0012I Integer solution of 32.562159 found by heuristic after 6503 iterations and 4 nodes (1.42 seconds)
# Cbc0030I Thread 0 used 5 times,  waiting to start 0.14903736, 0.144542 cpu time, 25 locks, 0.00017690659 locked, 3.8146973e-06 waiting for locks
# Cbc0030I Thread 1 used 1 times,  waiting to start 0.20693398, 0.073131 cpu time, 6 locks, 3.8146973e-05 locked, 8.2969666e-05 waiting for locks
# Cbc0030I Thread 2 used 0 times,  waiting to start 0.22410798, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 3 used 0 times,  waiting to start 0.19091511, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 4 used 0 times,  waiting to start 0.16385293, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Thread 5 used 0 times,  waiting to start 0.1235919, 0 cpu time, 0 locks, 0 locked, 0 waiting for locks
# Cbc0030I Main thread 0.12001324 waiting for threads,  18 locks, 4.5776367e-05 locked, 0 waiting for locks
# Cbc0001I Search completed - best objective 32.562159312774, took 6768 iterations and 6 nodes (1.55 seconds)
# Cbc0032I Strong branching done 1188 times (59733 iterations), fathomed 3 nodes and fixed 0 variables
# Cbc0035I Maximum depth 1, 41 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 16.3535
# Probing was tried 700 times and created 0 cuts of which 28 were active after adding rounds of cuts (0.183 seconds)
# Gomory was tried 700 times and created 12103 cuts of which 0 were active after adding rounds of cuts (0.820 seconds)
# Knapsack was tried 700 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.193 seconds)
# Clique was tried 700 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.028 seconds)
# MixedIntegerRounding2 was tried 700 times and created 0 cuts of which 0 were active after adding rounds of cuts (1.236 seconds)
# FlowCover was tried 700 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.028 seconds)
# TwoMirCuts was tried 700 times and created 357 cuts of which 0 were active after adding rounds of cuts (0.466 seconds)
# ZeroHalf was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
#
# Result - Optimal solution found
#
# Objective value:                32.56215931
# Enumerated nodes:               6
# Total iterations:               6768
# Time (CPU seconds):             1.46
# Time (Wallclock seconds):       1.58
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.46   (Wallclock seconds):       1.58
#
# 1
# xAppanoose 1.0
# xDavis 1.0
# xMonroe 1.0
# xWayne 1.0
# xIowa 1.0
# xPolk 1.0
# xStory 1.0
# xFranklin 1.0
# xClarke 1.0
# xDecatur 1.0
# xLucas 1.0
# xWarren 1.0
# xWapello 1.0
# xHardin 1.0
# xMarshall 1.0
# xJefferson 1.0
# xWashington 1.0
# xKeokuk 1.0
# xPoweshiek 1.0
# xJasper 1.0
# xMahaska 1.0
# xMarion 1.0

# %%
import csv

file = open('ia_districts.csv', 'w')
w = csv.writer(file)
w.writerow(["district", "precinct"])
for i in range(len(districts)):
    for j in range(len(districts[i])):
        w.writerow([i + 1, districts[i][j]])
file.close()
